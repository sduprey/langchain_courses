# %% [markdown]
# # Context rot & lost-in-the-middle
#
# **Session 5 · Track A · local Ollama**
#
# Show that more context isn't always better, and position matters.

# %%
import sys; sys.path.append('..')  # so `utils` and `eval` import from the repo root
from utils import ask

# %% [markdown]
# ## Your tasks
#
# 1. Put the key fact at the start, middle, then end of a long context.
# 2. Ask the same question each time; compare accuracy.
# 3. Add irrelevant chunks and watch quality drop.

# %%
# TODO: your code here
