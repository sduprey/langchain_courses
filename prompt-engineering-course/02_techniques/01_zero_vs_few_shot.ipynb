# %% [markdown]
# # Zero-shot vs few-shot
#
# **Session 2 · Track A · local Ollama**
#
# Start zero-shot; add examples only when it fails.

# %%
import sys; sys.path.append('..')  # so `utils` and `eval` import from the repo root
from utils import ask

# %% [markdown]
# ## Your tasks
#
# 1. Write a zero-shot classifier prompt for billing/bug/other.
# 2. Add 3 few-shot examples; compare on 5 tricky tickets.
# 3. # TODO: your code here

# %%
# TODO: your code here
