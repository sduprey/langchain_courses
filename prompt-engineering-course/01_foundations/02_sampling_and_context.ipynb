# %% [markdown]
# # Sampling: temperature, top-p, and determinism
#
# **Session 1 · Track A · local Ollama**
#
# Feel how decoding knobs change outputs, and when to pin temperature to 0.

# %%
import sys; sys.path.append('..')  # so `utils` and `eval` import from the repo root
from utils import ask

# %% [markdown]
# Run the SAME prompt several times at two temperatures and compare variability.

# %%
prompt = "Give me a one-line startup idea for a bakery."
print("--- temperature 0 (repeatable) ---")
for _ in range(3): print(ask(prompt, temperature=0))
print("--- temperature 1 (varied) ---")
for _ in range(3): print(ask(prompt, temperature=1))

# %% [markdown]
# ## Your tasks
#
# 1. When would you WANT temperature 0? When higher?
# 2. Find a task where temperature 0 still varies run-to-run.
# 3. # TODO: your code here
