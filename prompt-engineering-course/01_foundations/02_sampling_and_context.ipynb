# %% [markdown]
# # Sampling: temperature, top-p, and determinism
#
# **Session 1 · Track A · local Ollama**
#
# Feel how decoding knobs change outputs, and when to pin temperature to 0.

# %%
import sys; sys.path.append('..')  # so `utils` and `eval` import from the repo root
from utils import ask

# %% [markdown]
# Run the SAME prompt several times at two temperatures and compare variability.

# %%
prompt = "Give me a one-line startup idea for a bakery."
print("--- temperature 0 (repeatable) ---")
for _ in range(3): print(ask(prompt, temperature=0))
print("--- temperature 1 (varied) ---")
for _ in range(3): print(ask(prompt, temperature=1))
# Out:
# --- temperature 0 (repeatable) ---
# ---------------------------------------------------------------------------
# ResponseError                             Traceback (most recent call last)
# Cell In[2], line 3
#       1 prompt = "Give me a one-line startup idea for a bakery."
#       2 print("--- temperature 0 (repeatable) ---")
# ----> 3 for _ in range(3): print(ask(prompt, temperature=0))
#       4 print("--- temperature 1 (varied) ---")
#       5 for _ in range(3): print(ask(prompt, temperature=1))
#
# File ~\Documents\GitHub\langchain_courses\prompt-engineering-course\01_foundations\..\utils\llm.py:42, in ask(prompt, system, temperature)
#      40     msgs.append({"role": "system", "content": system})
#      41 msgs.append({"role": "user", "content": prompt})
# ---> 42 return chat(msgs, temperature=temperature)
#
# File ~\Documents\GitHub\langchain_courses\prompt-engineering-course\01_foundations\..\utils\llm.py:20, in chat(messages, temperature, **kwargs)
# ...

# %% [markdown]
# ### Worked example
#
# Measure how many *distinct* answers you get at each temperature. Swap the prompt for a creative vs a factual task and compare.

# %%
# Worked example: quantify output variability at each temperature
def variability(prompt, temperature, n=5):
    outs = [ask(prompt, temperature=temperature).strip() for _ in range(n)]
    return outs, len(set(outs))

for temp in (0, 0.7, 1.0):
    outs, distinct = variability("Give me a one-line startup idea for a bakery.", temp)
    print(f"temp={temp}: {distinct}/{len(outs)} distinct")
    for o in outs:
        print("   ", o[:70])

# %% [markdown]
# ## Your turn - vary the example
#
# 1. Swap in a purely factual prompt ("What is 17 * 23?"). Does temperature still matter?
# 2. Find a task where temperature 0 *still* varies run-to-run.
# 3. When would you WANT temperature 0 in production? When would you raise it?

# %%
# Your variation here - copy the worked example above and change ONE thing, then re-run
